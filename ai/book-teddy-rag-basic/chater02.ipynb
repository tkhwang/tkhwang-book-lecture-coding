# %%
from langchain_teddynote import logging

logging.langsmith("CH01-Basic")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH01-Basic

# %%
from langchain_teddynote.models import MultiModal
from langchain_openai import ChatOpenAI
from langchain_teddynote.messages import stream_response

llm = ChatOpenAI(
    temperature=0.1,
    model_name="gpt-4o-mini",
)

multimodal_llm = MultiModal(llm)

IMAG_URL = "https://images.ctfassets.net/kftzwdyauwt9/40in10B8KtAGrQvwRv5cop/8241bb17c283dced48ea034a41d7464a/chatgpt_diagram_light.png?w=1920&q=80&fm=webp"

answer = multimodal_llm.stream(IMAG_URL)
final_answer = stream_response(answer, return_output=True)

print(final_answer)
# Out:
# <img src="data:image/unknown;base64,..."/>
# The images depict two flowcharts that illustrate different processes related to reinforcement learning and storytelling.
#
# ### Left Flowchart: Explaining Reinforcement Learning
#
# 1. **Top Node**: The flowchart begins with the task of explaining reinforcement learning to a 6-year-old. This sets the context for the entire flow.
#
# 2. **Options (A, B, C, D)**:
#    - **A**: "In reinforcement learning, the agent is..." suggests an introduction to the concept of an agent in reinforcement learning.
#    - **B**: "Explain rewards..." likely refers to the importance of rewards in the learning process.
#    - **C**: "In machine learning..." indicates a broader context, possibly linking reinforcement learning to other types of machine learning.
#    - **D**: "We give treats and punishments to teach..." simplifies the concept by relating it to familiar ideas of rewards and punishments.
#
# ...
